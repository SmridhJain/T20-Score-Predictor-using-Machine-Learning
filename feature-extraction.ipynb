# %%
import pandas as pd
import pickle

# %%
df = pickle.load(open('dataset_level2.pkl','rb'))

# %%
#batting team
#bowling team
#city
#current score
#ball left
#wickets left
#current rr
#last five over mei kitne run
#final score

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %%
#use venue ka first word to fill city
import numpy as np
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply (lambda x : x[0]),df['city'])

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(['venue'],axis=1,inplace= True)

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# ...

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# ...

# %%
df['current_score'] = df.groupby('match_id')['runs'].cumsum()
# Out:
# C:\Users\Smridh\AppData\Local\Temp\ipykernel_8772\190681986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['current_score'] = df.groupby('match_id')['runs'].cumsum()

# %%
# to get ball number and over column
df['ball_no'] = df['ball'].apply(lambda x : str(x).split(".")[1])
df['over'] = df['ball'].apply(lambda x : str(x).split(".")[0])
df
# Out:
# C:\Users\Smridh\AppData\Local\Temp\ipykernel_8772\3863352021.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df['ball'].apply(lambda x : str(x).split(".")[1])
# C:\Users\Smridh\AppData\Local\Temp\ipykernel_8772\3863352021.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df['ball'].apply(lambda x : str(x).split(".")[0])
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# ...

# %%
df['balls_bowled'] = (df['over'].astype('int')*6)+ df['ball_no'].astype('int')
# Out:
# C:\Users\Smridh\AppData\Local\Temp\ipykernel_8772\1942952409.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_bowled'] = (df['over'].astype('int')*6)+ df['ball_no'].astype('int')

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score ball_no over  balls_bowled
# 0    Melbourne              0       1    0             1
# ...

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x : 0 if x < 0 else x)
# Out:
# C:\Users\Smridh\AppData\Local\Temp\ipykernel_8772\3077786453.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = 120 - df['balls_bowled']
# C:\Users\Smridh\AppData\Local\Temp\ipykernel_8772\3077786453.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = df['balls_left'].apply(lambda x : 0 if x < 0 else x)

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x : 0 if x == '0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].cumsum()
df['wickets_left'] = 10 - df['player_dismissed']
# Out:
# C:\Users\Smridh\AppData\Local\Temp\ipykernel_8772\3802853957.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x : 0 if x == '0' else 1)
# C:\Users\Smridh\AppData\Local\Temp\ipykernel_8772\3802853957.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype('int')
# C:\Users\Smridh\AppData\Local\Temp\ipykernel_8772\3802853957.py:3: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 8
# 122       964    Sri Lanka    Australia  19.4     0                 8
# 123       964    Sri Lanka    Australia  19.5     0                 9
# 124       964    Sri Lanka    Australia  19.6     2                 9
# 125       964    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score ball_no over  balls_bowled  balls_left  \
# ...

# %%
#add current run rate column
df['crr'] = (df['current_score']*6)/df['balls_bowled']
# Out:
# C:\Users\Smridh\AppData\Local\Temp\ipykernel_8772\3858855363.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
#runs in last five overs
groups = df.groupby('match_id')
match_ids = df['match_id'].unique()
last_five = []

# %%
for id in match_ids:
    last_five.extend(groups.get_group(id)['runs'].rolling(window=6*5).sum().tolist())

# %%
df['last_five'] = last_five
# Out:
# C:\Users\Smridh\AppData\Local\Temp\ipykernel_8772\1595651733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five'] = last_five

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 8
# 122       964    Sri Lanka    Australia  19.4     0                 8
# 123       964    Sri Lanka    Australia  19.5     0                 9
# 124       964    Sri Lanka    Australia  19.6     2                 9
# 125       964    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score ball_no over  balls_bowled  balls_left  \
# ...

# %%
#final_score
final_df = df.groupby('match_id')['runs'].sum().reset_index().merge(df,on='match_id')

# %%
final_df
# Out:
#        match_id  runs_x batting_team bowling_team  ball  runs_y  \
# 0             2     168    Australia    Sri Lanka   0.1       0
# 1             2     168    Australia    Sri Lanka   0.2       0
# 2             2     168    Australia    Sri Lanka   0.3       1
# 3             2     168    Australia    Sri Lanka   0.4       2
# 4             2     168    Australia    Sri Lanka   0.5       0
# ...         ...     ...          ...          ...   ...     ...
# 50496       964     128    Sri Lanka    Australia  19.3       1
# 50497       964     128    Sri Lanka    Australia  19.4       0
# 50498       964     128    Sri Lanka    Australia  19.5       0
# 50499       964     128    Sri Lanka    Australia  19.6       2
# 50500       964     128    Sri Lanka    Australia  19.7       1
#
#        player_dismissed       city  current_score ball_no over  balls_bowled  \
# 0                     0  Melbourne              0       1    0             1
# ...

# %%
final_df = final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
#check which values are null
final_df.isnull().sum()
# Out:
# batting_team         0
# bowling_team         0
# city                 0
# current_score        0
# balls_left           0
# wickets_left         0
# crr                  0
# last_five        12024
# runs_x               0
# dtype: int64

# %%
final_df.dropna(inplace=True)
# Out:
# C:\Users\Smridh\AppData\Local\Temp\ipykernel_8772\2709626079.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
#shufling df so that bias doesnt develop
final_df = final_df.sample(final_df.shape[0])
import pickle
pickle.dump(final_df,open('final_df.pkl','wb'))

# %%
import pickle 
final_df = pickle.load(open('final_df.pkl','rb'))

# %%
#Train-Test-Split
X = final_df.drop(['runs_x'],axis=1)
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 1)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
trf = ColumnTransformer([
    ('trf', OneHotEncoder(sparse_output=False), ['batting_team', 'bowling_team', 'city'])
], remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
#prediction
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)

# %%
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9868136644363403
# 1.6493527150699354

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
final_df['city']
# Out:
# 30242           Auckland
# 4199     Mount Maunganui
# 13041             Lahore
# 22287           Hamilton
# 43247          Cape Town
#               ...
# 46564       Johannesburg
# 11290         Wellington
# 16386          Cape Town
# 20958             London
# 42936           Adelaide
# Name: city, Length: 38477, dtype: object

# %%
eligible_cities
# Out:
# ['Colombo',
#  'Mirpur',
#  'Johannesburg',
#  'Dubai',
#  'Auckland',
#  'Cape Town',
#  'London',
#  'Pallekele',
#  'Barbados',
#  'Sydney',
#  'Melbourne',
#  'Durban',
#  'St Lucia',
#  'Wellington',
#  'Lauderhill',
#  'Hamilton',
#  'Centurion',
#  'Manchester',
#  'Abu Dhabi',
#  'Mumbai',
#  'Nottingham',
#  'Southampton',
#  'Mount Maunganui',
#  'Chittagong',
#  'Kolkata',
#  'Lahore',
#  'Delhi',
#  'Nagpur',
#  'Chandigarh',
#  'Adelaide',
#  'Bangalore',
#  'St Kitts',
#  'Cardiff',
#  'Christchurch',
#  'Trinidad']

# %%
final_df
# Out:
#        batting_team  bowling_team             city  current_score  balls_left  \
# 30242  South Africa   New Zealand         Auckland            151           7
# 4199       Pakistan   New Zealand  Mount Maunganui             97          45
# 13041    Bangladesh      Pakistan           Lahore            123           9
# 22287   New Zealand   West Indies         Hamilton             64          76
# 43247       England  South Africa        Cape Town             52          79
# ...             ...           ...              ...            ...         ...
# 46564  South Africa     Sri Lanka     Johannesburg             74          50
# 11290         India   New Zealand       Wellington             91          44
# 16386    Bangladesh     Australia        Cape Town            112          17
# 20958  South Africa   West Indies           London             87          59
# 42936     Australia  South Africa         Adelaide            108          26
#
# ...
